# %%
 #EJERCICIO 1 Completa una decisión simple

edad = 20
if edad>=18:
  print("Mayor de edad")
# Out:
# Mayor de edad

# %%
# EJERCICIO 2 grega la ruta alternativa

Temperatura = 32

if Temperatura >30:
  print("Alta")

if Temperatura <= 30:
  print("Normal")
# Out:
# Alta

# %%
#EJERCICIO 3 predice la salida
numero=7

if numero% 2 == 0:
  print("Par")

else:
  print("Impar")
# Out:
# Impar

# %%
#EJERCIO 4 completa la clasificación
nota= 2.5

if nota >= 4.5:
  print("Excelente")

elif nota >=4.0:
  print("Muy buen desempeño")

elif nota >= 3.0:
  print("Aprobado")

else:
  print("No aprobado")
# Out:
# No aprobado

# %%
#Ejercicio 5 Corrige el orden
nota= 4.8

if nota >= 4.5:
  print("Excelente")
elif nota >= 3.0:
  print("Aprobado")
# Out:
# Excelente

# %%
#EJERCICO 6 Traza la ejecución
valor = 12
if valor < 15:
    print("C")
elif valor < 10:
    print("B")
elif valor < 5:
    print("A")
else:
    print("D")
# Out:
# C

# %%
#EJERCICO 7 Acceso con dos requisitos

usuario_activo= True
tiene_permiso= True

if usuario_activo and tiene_permiso:
  print("Acceso permitido")

else:
  print("Acceso denegado")
# Out:
# Acceso permitido

# %%
#EJERCICIO 8 Dos rutas válidas

correo_valido = False
telefono_valido = True

if correo_valido or telefono_valido:
  print("continuar registro")

else:
  print("Faltan datos de contacto")
# Out:
# continuar registro

# %%
#EJERCICIO 9 Usa negación

cuenta_bloqueada = False

if not cuenta_bloqueada:
  print("Puede operar")
# Out:
# Puede operar

# %%
#EJERCIO 10  Recorre del 1 al 5

for numero in range (1,6):
  print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#EJERCIO 11 Recorre con paso

for numero in range (2,11,2):
  print(numero)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#EJERCIO 12 Predice el acumulado

suma =0

for i in range(1,4):
  suma = suma + i

  print(suma)

# %% [markdown]
# #  suma = 6

# %%
#EJERCIO 13 Completa el contador

numero = 1

while numero <=5:
  print (numero)
  numero = numero +1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#EJERCICIO 14 Encuentra el ciclo infinito
 numero = 1

while numero <= 5
  print (numero)

# %% [markdown]
# numero = numero +1

# %%
# EJERCICIO 15 Control de intentos

intentos = 0

while intentos <3:
  clave= input("ingrese la clave:")
  intentos:  intentos + 1

  print("Proceso finalizado")
# Out:
# ingrese la clave:1
# Proceso finalizado
# ingrese la clave:2
# Proceso finalizado
# ingrese la clave:3
# Proceso finalizado
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1133/2416915346.py in <cell line: 0>()
#       4
#       5 while intentos <3:
# ----> 6   clave= input("ingrese la clave:")
#       7   intentos:  intentos + 1
#       8
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# #EJERCICIO 16  ¿for o while?
# Procesar exactamente 10 mediciones. ____FOR_____
# Pedir una clave hasta que sea correcta. ____WHILE_____
# Imprimir los números del 1 al 20. ___FOR______
# Repetir un cálculo hasta que el error sea menor que 0.01. __WHILE______

# %%
#EJERCICIO 17 Combina for + if

for numero in range (1,12):
 if numero % 3==0:

  print(numero)
# Out:
# 3
# 6
# 9

# %%
#EJRCICIO 18 Predice antes de ejecutar

for numero in range (1,8):

 if numero <3:
   print(numero,"A")

 elif numero <6:
   print(numero,"B")

 else:
   print(numero,"C")

# %% [markdown]
# 1=A
# 2=A
# 3=B
# 4=B
# 5=B
# 6=C
# 7=C

# %%
#EJERICICO 19 Traduce una decisión

nota = float(input("Nota: "))
if nota >= 3.0:
  print("Aprobado")
else:
  print("No aprobado")
# Out:
# Nota: 4.5
# Aprobado

# %%
#EJERICICO 20  Traduce una repetición

for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# EJERCIO Clasificación de temperaturas

for Temperatura  in range(18,25)
  t= float (input("Temperatura:"))
